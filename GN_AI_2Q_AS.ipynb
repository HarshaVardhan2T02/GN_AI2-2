# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshaVardhan2T02/GN_AI2-2/blob/GN-AI-2%2F2/GN_AI_2Q_AS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.optimize import linprog

# Coefficients for the objective function (negative for maximization)
c = [-6, -5]

# Coefficients for the inequality constraints
A = [
    [1, 1],   # Milk constraint
    [3, 2]    # Choco constraint
]

# Right-hand side of the inequality constraints
b = [5, 12]

# Bounds for variables (non-negativity)
x0_bounds = (0, None)  # A >= 0
x1_bounds = (0, None)  # B >= 0

# Solve the linear programming problem
result = linprog(c, A_ub=A, b_ub=b, bounds=[x0_bounds, x1_bounds], method='highs')

# Display the results
if result.success:
    print(f"Optimal number of A to produce: {result.x[0]}")
    print(f"Optimal number of B to produce: {result.x[1]}")
    print(f"Maximum profit: {-result.fun}")
else:
    print("No solution found!")
# Out:
# Optimal number of A to produce: 2.0
# Optimal number of B to produce: 3.0
# Maximum profit: 27.0

# %%
from scipy.optimize import linprog

c = [-50, -120]
A = [
    [1, 1],
    [7000, 2000],
    [10, 30]
]
b = [110, 700000, 1200]
x0_bounds = (0, None)
x1_bounds = (0, None)

result = linprog(c, A_ub=A, b_ub=b, bounds=[x0_bounds, x1_bounds], method='highs')

if result.success:
    print(f"Optimal area for Wheat: {result.x[0]:.2f} hectares")
    print(f"Optimal area for Barley: {result.x[1]:.2f} hectares")
    print(f"Maximum profit: Rs. {-result.fun:.2f}")
else:
    print("No solution found!")
# Out:
# Optimal area for Wheat: 97.89 hectares
# Optimal area for Barley: 7.37 hectares
# Maximum profit: Rs. 5778.95
